# %% [markdown]
# [< list of demos](Introduction.ipynb#demos)
#
# <a id='top'></a>
# # Barycentric radial velocity _(single star)_
#
# This demo shows how to calculate barycentric radial velocity for a list of UTC Julian dates, using τ Ceti as an example.

# %% [markdown]
# ##### Arguments:
#
# `-p HD10700` - primary star: τ Ceti
#
# `-i HARPS` - instrument: HARPS
#
# `-t '2450000 2453000 10'` - epochs, JD from 2450000 to 2453000, every 10 days
#
# `-m emulate` - PEXO mode
#
# `-v 'JDutc ZB'` - output variables
#
# `-o ../results/bary-out.txt` - output file path

# %% [markdown]
# ## Run the code
#
# Execute PEXO with the command below. This may take under 1 minute to compute.

# %%
# cd into the code directory
# %cd ../code

# run PEXO via the R script
! Rscript pexo.R -p HD10700 -i HARPS -t '2450000 2453000 10' -m emulate -v 'JDutc ZB' -o ../results/bary-out.txt
# Out:
# /home/timberhill/repositories/pexo/code
# Warning message:
# package ‘optparse’ was built under R version 3.6.3
# Loading required package: polynom
# Warning messages:
# 1: package ‘orthopolynom’ was built under R version 3.6.3
# 2: package ‘polynom’ was built under R version 3.6.3
#
# Attaching package: ‘pracma’
#
# The following object is masked from ‘package:polynom’:
#
#     integral
#
# Warning message:
# package ‘pracma’ was built under R version 3.6.3
# Warning message:
# package ‘foreach’ was built under R version 3.6.3
# Loading required package: iterators
# Loading required package: parallel
# Warning messages:
# 1: package ‘doMC’ was built under R version 3.6.3
# 2: package ‘iterators’ was built under R version 3.6.3
#
# Attaching package: ‘e1071’
#
# The following object is masked from ‘package:pracma’:
#
#     sigmoid
#
# Warning message:
# package ‘e1071’ was built under R version 3.6.3
# Warning message:
# package ‘MASS’ was built under R version 3.6.3
# ...

# %% [markdown]
# ## Output
#
# The output file (`bary-out.txt`) contains a table with 3 columns. Julian dates are divided into integer and decimal parts to preserve precision, and the barycentric correction is expressed as redshift.

# %%
from utilities import Table
Table("../results/bary-out.txt", digits=24)
# Out:
# <table style="text-align: left; font-size: 10pt"><tr><th style="text-align: right; padding: 7px;">JDutc1</th><th style="text-align: right; padding: 7px;">JDutc2</th><th style="text-align: right; padding: 7px;">ZB</th></tr><tr><td style="text-align: right; padding: 7px;">2450000</td><td style="text-align: right; padding: 7px;">0</td><td style="text-align: right; padding: 7px;">0.0000000356393283773571</td></tr><tr><td style="text-align: right; padding: 7px;">2450010</td><td style="text-align: right; padding: 7px;">0</td><td style="text-align: right; padding: 7px;">-0.0000150477512517178</td></tr><tr><td style="text-align: right; padding: 7px;">2450020</td><td style="text-align: right; padding: 7px;">0</td><td style="text-align: right; padding: 7px;">-0.0000302848580082671</td></tr><tr><td style="text-align: right; padding: 7px;">2450030</td><td style="text-align: right; padding: 7px;">0</td><td style="text-align: right; padding: 7px;">-0.0000446032860292878</td></tr><tr><td style="tex
# ...

# %% [markdown]
# The plot below shows the barycentric movement in km/s.

# %%
from utilities import Plot
p = Plot("../results/bary-out.txt", factors=(1, 299792.458)).add_plot(xcol=["JDutc1", "JDutc2"], ycol="ZB")
o=p.axis.set_xlabel("JD UTC, days")
o=p.axis.set_ylabel("Barycentric RV, km/s")
